# %% [markdown]
# ## Week 2

# %% [markdown]
# ### Exercise:
# Use and experience methods from previous lessons with given data. Try to search for other pandas methods to analyze the data such as `groupby()` and `read_csv()`.

# %%
# You can find covid related data under project's data folder 
base_url = "../adalovelace/data-science/data/covid/"
infected_dataset_url =  base_url + "time_series_covid19_confirmed_global.csv"
recovered_dataset_url = base_url + "time_series_covid19_recovered_global.csv"
deaths_dataset_url = base_url + "time_series_covid19_deaths_global.csv"

# %% [markdown]
# #### Solution:

# %%
import pandas as pd

# %%
# Your code goes here

df = pd.read_csv(infected_dataset_url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 311.8+ KB

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
df.shape
# Out:
# (266, 150)

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
df.tail()
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# 261        0        0        0        0        0  ...     499     513     513
# 262        0        0        0        0        0  ...     482     484     496
# 263        0        0        0        0        0  ...     141     141     141
# 264        0        0        0        0        0  ...    4453    4529    4609
# 265        0        0        0        0        0  ...       4       4       4
#
# ...

# %%
df1 = pd.read_csv(recovered_dataset_url )
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 296.6+ KB

# %%
df1.shape
# Out:
# (253, 150)

# %%
df1.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
df1.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...    1830    1875    2171    2651     3013
# 1        0        0        0  ...     925     938     945     960      980
# 2        0        0        0  ...    6631    6717    6799    6951     7074
# 3        0        0        0  ...     741     744     751     757      759
# 4        0        0        0  ...      24      24      38      38       40
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
df2 = pd.read_csv(deaths_dataset_url)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 311.8+ KB

# %%
df2.shape
# Out:
# (266, 150)

# %%
df2.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...     327     357     369     384      405
# 1        0        0        0  ...      34      34      34      34       34
# 2        0        0        0  ...     698     707     715     724      732
# 3        0        0        0  ...      51      51      51      51       51
# 4        0        0        0  ...       4       4       4       4        4
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# ...

# %%
df2.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
df2.describe().T
# Out:
#          count         mean          std       min        25%       50%  \
# Lat      266.0    21.148043    24.909990  -51.7963   6.907750  23.48810
# Long     266.0    22.538640    70.466256 -135.0000 -18.093125  20.97265
# 1/22/20  266.0     0.063910     1.042337    0.0000   0.000000   0.00000
# 1/23/20  266.0     0.067669     1.043908    0.0000   0.000000   0.00000
# 1/24/20  266.0     0.097744     1.473615    0.0000   0.000000   0.00000
# ...        ...          ...          ...       ...        ...       ...
# 6/11/20  266.0  1584.439850  8527.744292    0.0000   2.000000  13.50000
# 6/12/20  266.0  1600.676692  8595.718952    0.0000   2.000000  14.00000
# 6/13/20  266.0  1616.718045  8659.119397    0.0000   2.000000  14.00000
# 6/14/20  266.0  1629.289474  8690.642967    0.0000   2.000000  14.00000
# 6/15/20  266.0  1642.477444  8728.402797    0.0000   2.000000  14.00000
#
#                 75%          max
# Lat       41.143200      71.7069
# Long      77.191525     178.0650
# ...

# %%
df2[df2["Country/Region"] == "Turkey"]
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 213            NaN         Turkey  38.9637  35.2433        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# 213        0        0        0        0  ...    4669    4692    4711    4729
#
#      6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 213     4746     4763     4778     4792     4807     4825
#
# [1 rows x 150 columns]

# %%
df2.groupby(df2["Country/Region"] == "Turkey").count().columns[4:]
